# %%
import re
import pandas as pd
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, GaussianNB
import spacy
from sklearn.decomposition import PCA

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# 2022-05-16 18:05:25.877256: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-16 18:05:25.877331: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 21.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from en-core-web-sm==3.2.0) (3.2.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: jinja2 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.27.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: setuptools in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (59.8.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.22.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: pathy>=0.3.5 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.63.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.1.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.1.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load('en_core_web_sm')

# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (3.3.2)
# Requirement already satisfied: requests in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from requests->vaderSentiment) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from requests->vaderSentiment) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from requests->vaderSentiment) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wooyoung/anaconda3/envs/metis/lib/python3.9/site-packages (from requests->vaderSentiment) (2021.10.8)

# %%
## Importing data csv file

df = pd.read_csv('Musical_instruments_reviews.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10261 entries, 0 to 10260
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      10261 non-null  object
#  1   asin            10261 non-null  object
#  2   reviewerName    10234 non-null  object
#  3   helpful         10261 non-null  object
#  4   reviewText      10254 non-null  object
#  5   overall         10261 non-null  float64
#  6   summary         10261 non-null  object
#  7   unixReviewTime  10261 non-null  int64
#  8   reviewTime      10261 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 721.6+ KB

# %%
df[['reviewText', 'overall']].head()
df['reviewText']= df['reviewText'].astype(str)

# %%
df['spacy_doc'] = list(nlp.pipe(df.reviewText))

df[['spacy_doc', 'overall']].head()
# Out:
#                                            spacy_doc  overall
# 0  (Not, much, to, write, about, here, ,, but, it...      5.0
# 1  (The, product, does, exactly, as, it, should, ...      5.0
# 2  (The, primary, job, of, this, device, is, to, ...      5.0
# 3  (Nice, windscreen, protects, my, MXL, mic, and...      5.0
# 4  (This, pop, filter, is, great, ., It, looks, a...      5.0

# %%
print('rate over 3.0 is ', len(df[df.overall > 3.0]))
print('rate under or equal to  3.0 is ', len(df[df.overall <= 3.0]))
ratio_value = 9022/1239
print(ratio_value)
# Out:
# rate over 3.0 is  9022
# rate under or equal to  3.0 is  1239
# 7.281678773204197

# %%
hib = [(len(df[df.overall > 3.0]), )]

# %%
five_reviews = df[df.overall > 3.0]

five_adj = [token.text.lower() for doc in
          five_reviews.spacy_doc 
          for token in doc
          if token.pos_=='ADJ']
# Out:
# ['much',
#  'crisp',
#  'lowest',
#  'same',
#  'affordable',
#  'better',
#  'added',
#  'small',
#  'old',
#  'reminiscent',
#  'next',
#  'expensive',
#  'pleasing',
#  'primary',
#  'noticeable',
#  'high',
#  'double',
#  'secure',
#  'little',
#  'nice',
#  'only',
#  'able',
#  'careful',
#  'great',
#  'good',
#  'heavy',
#  'great',
#  'last',
#  'great',
#  'good',
#  'worth',
#  'simple',
#  'perfect',
#  'several',
#  'best',
#  'great',
#  'wrong',
#  'wide',
#  'high',
#  'few',
#  'glad',
#  'expensive',
#  'expensive',
#  'sure',
#  'sturdy',
#  'reliable',
#  'pricier',
#  'bottom',
#  'own',
#  'possible',
#  'higher',
#  'higher',
#  'same',
#  'good',
#  'great',
#  'midi',
#  'perfect',
#  'great',
#  'only',
#  'unscrewed',
#  'sound',
#  'cool',
#  'nice',
#  'great',
#  'more',
#  'indestructable',
#  'electrician',
#  'more',
#  'third',
#  'fourth',
#  'light',
#  'cheaper',
#  'hard',
#  'cheaper',
#  'few',
#  'extra',
#  'little',
#  'durable',
#  'shipped-',
#  'limited',
#  'unshielded',
#  'more',
#  'better',
#  'great',
#  'sure',
#  'cool',
#  'cheap',
#  'able',
#  'rattle',
#  'black',
#  'other',
#  'cool',
#  'shorter',
#  'red',
#  'black',
#  'easier',
#  'different',
#  'green',
#  'good',
#  'good',
#  'extra',
#  'good',
#  'good',
#  'great',
#  'flat',
#  'rockband',
#  'great',
#  'firm',
#  'reputable',
#  'thin',
#  'wrong',
#  'prime',
#  'happy',
#  'high',
#  'longer',
#  'perfect',
#  'wrong',
#  'great',
#  'midi',
#  'secure',
#  'uneven',
#  'sure',
#  'correct',
#  'good',
#  'fine',
#  'affordable',
#  'large',
#  'shorter',
#  'mobile',
#  'strong',
#  'sturdy',
#  'inexpensive',
#  'good',
#  'professional',
#  'satisfied',
#  'good',
#  'good',
#  'good',
#  'long',
#  'good',
#  'small',
#  'perfect',
#  'other',
#  'connected',
#  'long',
#  'solo',
#  'live',
#  'nice',
#  'operational',
#  'good',
#  'hard',
#  'longer',
#  'obtainable',
#  'vocal',
#  'greatest',
#  'cheap',
#  'many',
#  'first',
#  'audio',
#  'good',
#  'fine',
#  'decent',
#  'exceptional',
#  'best',
#  'audio',
#  'cheap',
#  'proper',
#  'small',
#  'reliable',
#  'mic',
#  'sound',
#  'excellent',
#  'excellent',
#  'nice',
#  'solid',
#  'excellent',
#  'good',
#  'good',
#  'cheap',
#  'light',
#  'unplugging',
#  'inexpensive',
#  'electric',
#  'few',
#  'cheap',
#  'surprised',
#  'decent',
#  'decent',
#  'good',
#  'nice',
#  'fine',
#  'white',
#  'good',
#  'cheap',
#  'good',
#  'stiff',
#  'only',
#  'fine',
#  'sturdy',
#  'reasonable',
#  'professional',
#  'many',
#  'many',
#  'best',
#  'sure',
#  'better',
#  'good',
#  'nice',
#  'long',
#  'additional',
#  'sturdy',
#  'good',
#  'decent',
#  'new',
#  'first',
#  'hard',
#  'much',
#  'fine',
#  'other',
#  'several',
#  'excellent',
#  'expensive',
#  'rugged',
#  'happy',
#  'good',
#  'excellent',
#  'affordable',
#  'more',
#  'more',
#  'pretty',
#  'crappy',
#  'extra',
#  'better',
#  'soundproof',
#  'reliable',
#  'clean',
#  'excellent',
#  'usefull',
#  'second',
#  'other',
#  'shorter',
#  'first',
#  'high',
#  'more',
#  'last',
#  'few',
#  'real',
#  'high',
#  'extra',
#  'long',
#  'sturdy',
#  'good',
#  'great',
#  'several',
#  'different',
#  'perfect',
#  'decent',
#  'first',
#  'disappointed',
#  'good',
#  'low',
#  'repairable',
#  'effective',
#  'thick',
#  'great',
#  'durable',
#  'durable',
#  'good',
#  'solid',
#  'longer',
#  'extra',
#  'nice',
#  'high',
#  'white',
#  'good',
#  'good',
#  'multiple',
#  'great',
#  'terminal',
#  'durable',
#  'light',
#  'great',
#  'perfect',
#  'worth',
#  'high',
#  'low',
#  'satisfied',
#  'basic',
#  'black',
#  'electric',
#  'great',
#  'solid',
#  'great',
#  'rubbery',
#  'long',
#  'good',
#  'good',
#  'reliable',
#  'lasting',
#  'good',
#  'short',
#  'useful',
#  'span).these',
#  'nice',
#  'good',
#  'soft',
#  'good',
#  'short',
#  'good',
#  'particular',
#  'more',
#  'cheaper',
#  'best',
#  'excellent',
#  'good',
#  'strong',
#  'thick',
#  'identical',
#  'many',
#  'worth',
#  'overpriced',
#  'fantastic',
#  'key',
#  'few',
#  'more',
#  'higher',
#  'good',
#  'single',
#  'least',
#  'hard',
#  'great',
#  'lighter',
#  'surprised',
#  'significant',
#  'surprised',
#  'good',
#  'heavy',
#  'little',
#  'inconsequential',
#  'expensive',
#  'great',
#  'long',
#  'glad',
#  'reliable',
#  'good',
#  'good',
#  'sure',
#  'heavy',
#  'great',
#  'sturdy',
#  'high',
#  'little',
#  'very',
#  'expensive',
#  'professional',
#  'medium',
#  'sized',
#  'many',
#  'active',
#  'extra',
#  'expensive',
#  'strong',
#  'flexible',
#  'proper',
#  'better',
#  'few',
#  'worse',
#  'good',
#  'sweet',
#  'great',
#  'good',
#  'good',
#  'expensive',
#  'stiff',
#  'cheap',
#  'bad',
#  'great',
#  'great',
#  'nice',
#  'good',
#  'adapter',
#  'good',
#  'superb',
#  'digital',
#  'fine',
#  'handy',
#  'much',
#  'real',
#  'confusing',
#  'sure',
#  'similar',
#  'right',
#  'separate',
#  'unbalanced',
#  'unbalanced',
#  'unbalanced',
#  'balanced',
#  'unbalanced',
#  'mic',
#  'little',
#  'red',
#  'excellent',
#  'third',
#  'useable',
#  'portable',
#  'able',
#  'entire',
#  'simple',
#  'free',
#  'electromagnetic',
#  'cheap',
#  'pleased',
#  'primary',
#  'pricier',
#  'worth',
#  'extra',
#  'instrumental',
#  'live',
#  'several',
#  'visual',
#  'audio',
#  'professional',
#  'sinlge',
#  'small',
#  'light',
#  'gentle',
#  'short',
#  'mic',
#  'short',
#  'mic',
#  'aware',
#  'similar',
#  'heavy',
#  'longer',
#  'same',
#  'little',
#  'shotgun',
#  'mic',
#  'more',
#  'usual',
#  'adapter',
#  'little',
#  'more',
#  'big',
#  'minor',
#  'clean',
#  'other',
#  'same',
#  'great',
#  'single',
#  'true',
#  'insert',
#  'longer',
#  'hard',
#  'whole',
#  'excellent',
#  'flimsy',
#  'static',
#  'buzz',
#  'low',
#  'nice',
#  'insert',
#  'solid',
#  'tight',
#  'discernible',
#  'brilliant',
#  'economical',
#  'good',
#  'sure',
#  'convinced',
#  'great',
#  'same',
#  'common',
#  'separate',
#  'perfect',
#  'automatic',
#  'second',
#  'first',
#  'various',
#  'specific',
#  'insert',
#  'individual',
#  'efficient',
#  'flexible',
#  'great',
#  'audio',
#  'audio',
#  'custom',
#  'mobile',
#  'such',
#  'effective',
#  'other',
#  'good',
#  'dependable',
#  'great',
#  'small',
#  'great',
#  'small',
#  'stereo',
#  'large',
#  'much',
#  'few',
#  'most',
#  'separate',
#  'perfect',
#  'durable',
#  'handy',
#  'full',
#  'cheap',
#  'sufficient',
#  'many',
#  'cheap',
#  'thin',
#  'such',
#  'aware',
#  'cheap',
#  'unshielded',
#  'fair',
#  'ultra',
#  'cheap',
#  'right',
#  'other',
#  'hard',
#  'sure',
#  'other',
#  'complete',
#  'best',
#  'same',
#  'new',
#  'happier',
#  'sturdy',
#  'great',
#  'normal',
#  'straight',
#  'much',
#  'good',
#  'flexible',
#  'cheap',
#  'little',
#  'fine',
#  'small',
#  'right',
#  'same',
#  'right',
#  'affordable',
#  'small',
#  'effective',
#  'first',
#  'perfect',
#  'good',
#  'small',
#  'cheap',
#  'more',
#  'durable',
#  'sound',
#  'great',
#  'good',
#  'little',
#  'durable',
#  'stomp',
#  'worth',
#  'great',
#  'only',
#  'bad',
#  'durable',
#  'most',
#  'fine',
#  'great',
#  'little',
#  'more',
#  'good',
#  'clean',
#  'terrible',
#  'bad',
#  'good',
#  'great',
#  'great',
#  'low',
#  'good',
#  'right',
#  'long',
#  'right',
#  'fanciest',
#  'low',
#  'great',
#  'good',
#  'inexpensive',
#  'durable',
#  'frequent',
#  'good',
#  'cheap',
#  'electric',
#  'particular',
#  'cheap',
#  'accessible',
#  'best',
#  'great',
#  'flexible',
#  'firm',
#  'little',
#  'lower',
#  'thick',
#  'old',
#  'funky',
#  'particular',
#  'female',
#  'other',
#  'great',
#  'high',
#  'solid',
#  'long',
#  'solid',
#  'great',
#  'handy',
#  'many',
#  'good',
#  'affordable',
#  'only',
#  'little',
#  'stuck',
#  'little',
#  'bulky',
#  'tight',
#  'fitting',
#  'certain',
#  'great',
#  'affordable',
#  'nice',
#  'little',
#  'low',
#  'high',
#  'local',
#  'basic',
#  'female',
#  'regular',
#  'mic',
#  'vocal',
#  'bigger',
#  'only',
#  'female',
#  'male',
#  'short',
#  'short',
#  'mic',
#  'great',
#  'close',
#  'little',
#  'funny',
#  'vertical',
#  'great',
#  'solid',
#  'great',
#  'single',
#  'mic',
#  'audio',
#  'post',
#  'fine',
#  'good',
#  'good',
#  'important',
#  'great',
#  'right',
#  'solid',
#  'dual',
#  'perfect',
#  'live',
#  'important',
#  'good',
#  'good',
#  'clean',
#  'audio',
#  'hot',
#  'crap',
#  'stupid',
#  'separate',
#  'clean',
#  'audio',
#  'wireless',
#  'own',
#  'audio',
#  'top',
#  'superior',
#  'other',
#  'right',
#  'scratchy',
#  'good',
#  'several',
#  'worth',
#  'magic',
#  'noisy',
#  'static',
#  'good',
#  'electronic',
#  'musical',
#  'most',
#  'scratchy',
#  'noisy',
#  'crackly',
#  'similar',
#  'great',
#  'worth',
#  'several',
#  'various',
#  'more',
#  'jarring',
#  'new',
#  'more',
#  'great',
#  'fantastic',
#  'new',
#  'worth',
#  'little',
#  'few',
#  'more',
#  'great',
#  'decent',
#  'vocal',
#  'good',
#  'surprised',
#  'nice',
#  'good',
#  'good',
#  "money,,can't",
#  'wrong',
#  'cheep',
#  'nice',
#  'only',
#  'same',
#  'other',
#  'good',
#  'hot',
#  'other',
#  'near',
#  'weekly',
#  'less',
#  'several',
#  'good',
#  'casual',
#  'empirical',
#  'much',
#  'softer',
#  'mic',
#  'cheap',
#  'important',
#  'same',
#  'unmixed',
#  'demonic',
#  'mic',
#  'mic',
#  'impressive',
#  'little',
#  'loose',
#  'live',
#  'same',
#  'best',
#  'good',
#  'several',
#  'fine',
#  'several',
#  'little',
#  'expensive',
#  'easy',
#  'worth',
#  'live',
#  'good',
#  'complicated',
#  'great',
#  'perfect',
#  'able',
#  'longer',
#  'narrower',
#  'other',
#  'little',
#  'mic',
#  'better',
#  'pronounced',
#  'butyl',
#  'mic',
#  'open',
#  'few',
#  'first',
#  'few',
#  'cheap',
#  'sound',
#  'impressed',
#  'cheap',
#  'thin',
#  'mic',
#  'much',
#  'greatest',
#  'soft',
#  'few',
#  'more',
#  'open',
#  'higher',
#  'mic',
#  'worth',
#  'extra',
#  'better',
#  'other',
#  'clean',
#  'crisp',
#  'perfect',
#  'excellent',
#  'great',
#  'happy',
#  'regular',
#  'medium',
#  'sized',
#  'large',
#  'pro',
#  'acoustic',
#  'sound',
#  'excellent',
#  'limited',
#  'bigger',
#  'full',
#  'off',
#  'true',
#  'less',
#  'flat',
#  'less',
#  'same',
#  'true',
#  'high',
#  'great',
#  'good',
#  'affordable',
#  'high',
#  'happy',
#  'fine',
#  'backup',
#  'longer',
#  'nice',
#  'great',
#  'hard',
#  'honest',
#  'gold',
#  'least',
#  'more',
#  'better',
#  'identical',
#  'first',
#  'bigger',
#  'heavier',
#  'different',
#  'interchangeable',
#  'identical',
#  'other',
#  'flatter',
#  'mid',
#  'brighter',
#  'more',
#  'equal',
#  'slight',
#  'ordinary',
#  'susceptible',
#  'much',
#  'vocal',
#  'live',
#  'least',
#  'awkward',
#  'able',
#  'little',
#  'high',
#  'few',
#  'db',
#  'human',
#  'vocal',
#  'likely',
#  'much',
#  'responsive',
#  'different',
#  'thin',
#  'little',
#  'identical',
#  'inferior',
#  'spare',
#  'excellent',
#  'good',
#  'other',
#  'unreachable',
#  'sturdy',
#  'good',
#  'unreasonable',
#  'other',
#  'identical',
#  'sturdy',
#  'reliable',
#  'lower',
#  'more',
#  'unbiased',
#  'actual',
#  'standard',
#  'enough',
#  'great',
#  'electric',
#  'southern',
#  'smooth',
#  'mid',
#  'same',
#  'next',
#  'few',
#  'great',
#  'big',
#  'pleased',
#  'old',
#  'little',
#  'good',
#  'next',
#  'happy',
#  'other',
#  'ready',
#  'mic',
#  'better',
#  'sure',
#  'worth',
#  'more',
#  'powered',
#  'clean',
#  'human',
#  'muted',
#  'dull',
#  'common',
#  'expensive',
#  'extra',
#  'least',
#  'larger',
#  'digital',
#  'audio',
#  'free',
#  'large',
#  'expensive',
#  'looking',
#  'cheap',
#  'high',
#  'half',
#  'front',
#  'cool',
#  'best',
#  'tiny',
#  'good',
#  'simple',
#  'live',
#  'expensive',
#  'good',
#  'clear',
#  'on',
#  'off',
#  'fantastic',
#  'great',
#  'future',
#  'same',
#  'basic',
#  'live',
#  'vocal',
#  'first',
#  'countless',
#  'modern',
#  'other',
#  'deep',
#  'closer',
#  'similar',
#  'vocal',
#  'fragile',
#  'expensive',
#  'closer',
#  'full',
#  'vocal',
#  'fuller',
#  'low',
#  'natural',
#  'muddy',
#  'muffled',
#  'pronounced',
#  'mic',
#  'mic',
#  'dramatic',
#  'genuine',
#  'mad',
#  'only',
#  'possible',
#  'vocal',
#  'available',
#  'modern',
#  'mic',
#  'off',
#  'best',
#  'past',
#  'different',
#  'variable',
#  'best',
#  'enduring',
#  'durable',
#  'wrong',
#  'close',
#  'good',
#  'solid',
#  'best',
#  'mid',
#  ...]

# %%
from collections import Counter

top_adj = Counter(five_adj).most_common(20)

top_data = pd.DataFrame(top_adj, columns = ['word', 'count'])

top_adj
# Out:
# [('great', 3728),
#  ('good', 3224),
#  ('other', 1841),
#  ('little', 1741),
#  ('more', 1520),
#  ('nice', 1515),
#  ('easy', 1299),
#  ('better', 916),
#  ('best', 835),
#  ('small', 795),
#  ('acoustic', 779),
#  ('new', 734),
#  ('few', 717),
#  ('different', 700),
#  ('same', 685),
#  ('perfect', 683),
#  ('many', 683),
#  ('cheap', 636),
#  ('much', 634),
#  ('high', 590)]

# %%
one_reviews = df[df.overall <= 3.0]

one_adj = [token.text.lower() for doc in
          one_reviews.spacy_doc
          for token in doc
          if token.pos_=='ADJ']

one_top_adj = Counter(one_adj).most_common(20)

# type(one_top_adj)
one_top_adj
# Out:
# [('good', 482),
#  ('other', 336),
#  ('great', 262),
#  ('more', 253),
#  ('better', 227),
#  ('little', 225),
#  ('cheap', 193),
#  ('same', 149),
#  ('nice', 144),
#  ('few', 125),
#  ('new', 116),
#  ('small', 115),
#  ('much', 110),
#  ('bad', 110),
#  ('low', 101),
#  ('first', 100),
#  ('different', 99),
#  ('high', 96),
#  ('sure', 96),
#  ('hard', 92)]

# %%
data = pd.DataFrame(one_top_adj, columns = ['word', 'count'])
data
# Out:
#          word  count
# 0        good    482
# 1       other    336
# 2       great    262
# 3        more    253
# 4      better    227
# 5      little    225
# 6       cheap    193
# 7        same    149
# 8        nice    144
# 9         few    125
# 10        new    116
# 11      small    115
# 12       much    110
# 13        bad    110
# 14        low    101
# 15      first    100
# 16  different     99
# 17       high     96
# 18       sure     96
# 19       hard     92

# %%
word_list = list(top_data.word) + list(data.word)
no_dup_word_list = sorted(set(word_list), key=lambda x: word_list.index(x))
# (no_dup_word_list)


count_list = [(3728, 3224, 1841, 1741, 1520, 1515, 1299, 916, 835, 795, 779, 734, 717, 700, 685, 683, 683, 636, 634, 590, 0, 0, 0, 0, 0),
             (262, 482, 336, 225, 253, 144, 0, 227, 0, 115, 0, 116, 125, 99, 149, 0, 0, 193, 110, 96, 110, 101, 100, 96, 92)]
review_word = pd.DataFrame(count_list, columns = no_dup_word_list)
review_word.iloc[1] = review_word.iloc[1] * ratio_value

review_word = review_word.drop(['great', 'good', 'other', 'little', 'more'], axis=1)

# %%
pca = PCA(n_components = 2)
pca.fit(review_word)
pca_3d_components = pca.components_
pca_3d_components
# Out:
# array([[-0.16309917, -0.45422052,  0.25768573, -0.29197393,  0.01482355,
#         -0.27239244,  0.03869957,  0.06755957,  0.00730326,  0.13985731,
#         -0.23882418, -0.23882418,  0.26902303,  0.05838942,  0.03812836,
#          0.28007981,  0.25716419,  0.25461801,  0.24443329,  0.23424857],
#        [-0.9307301 ,  0.07580983, -0.05718253,  0.0712601 , -0.00444236,
#          0.06848817, -0.17949344,  0.17967094,  0.18309038, -0.0191846 ,
#          0.04531864,  0.04531864, -0.051283  , -0.00711604, -0.00841502,
#         -0.0661247 , -0.05269923,  0.02873393,  0.01302932, -0.03927376]])

# %%
pca.transform(review_word)
# Out:
# array([[-1.42992220e+03,  1.71253301e-13],
#        [ 1.42992220e+03,  9.87529382e-14]])

# %%
pca.explained_variance_ratio_
# Out:
# array([1.00000000e+00, 4.63484787e-32])
